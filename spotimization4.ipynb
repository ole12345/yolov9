# %%
# !git clone https://github.com/ole12345/yolov9.git

# %%
# !git pull

# %%
# %cd yolov9
# !pip install -r requirements.txt --quiet
# Out:
# /content/yolov9
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 110.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 90.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 52.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 4.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 41.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 18.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 4.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 91.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.0/83.0 kB 6.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 5.9 MB/s eta 0:00:00
# ...

# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /content/yolov9

# %%
# !mkdir -p {HOME}/weights
# !wget -P {HOME}/weights -q https://github.com/WongKinYiu/yolov9/releases/download/v0.1/gelan-c.pt
# !wget -P {HOME}/weights -q https://github.com/WongKinYiu/yolov9/releases/download/v0.1/gelan-s.pt

# %%
import os
import roboflow

#DATASET_NAME = "football-players-detection-3zvbc-snapb"
DATASET_NAME="ball-player-big"
roboflow.login()

rf = roboflow.Roboflow()
project = rf.workspace("ws-tmip7").project(DATASET_NAME)
dataset = project.version(1).download(model_format="yolov7",location=os.path.join(".","data",DATASET_NAME))
# Out:
# visit https://app.roboflow.com/auth-cli to get your authentication token.
# Paste the authentication token here: ··········
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to ./data/ball-player-big in yolov7pytorch:: 100%|██████████| 49061/49061 [00:07<00:00, 6778.30it/s]

# %%
# !python train.py --batch=16 --epochs 100 --img 640 --device 0 --min-items 0 --close-mosaic 15 --data data/ball-player-big/data.yaml --weights /content/drive/MyDrive/sportimization-5/sportimization-54/weights/best.pt --cfg models/detect/gelan-c-nc_2.yaml --hyp hyp.scratch-high.yaml --name sportimization-6 --workers 12

# %%
# !pip install onnx onnxruntime onnx-simplifier onnxruntime-gpu
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.0/16.0 MB 104.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.3/13.3 MB 104.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 63.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 291.5/291.5 MB 3.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 3.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 8.5 MB/s eta 0:00:00
# ...

# %%
import export
export.run(include=['onnx'],weights="/content/drive/MyDrive/sportimization-5/sportimization-54/weights/best_striped.pt",imgsz=(640,640),batch_size=1,opset=20, device=0,half=True)
# Out:
# YOLO 🚀 0fe7e90 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (NVIDIA L4, 22693MiB)
#
# Fusing layers...
# gelan-c-nc_2 summary: 387 layers, 25228630 parameters, 0 gradients, 101.8 GFLOPs
#
# PyTorch: starting from /content/drive/MyDrive/sportimization-5/sportimization-54/weights/best_striped.pt with output shape (1, 6, 8400) (49.1 MB)
#
# ONNX: starting export with onnx 1.17.0...
# ONNX: export success ✅ 1.7s, saved as /content/drive/MyDrive/sportimization-5/sportimization-54/weights/best_striped.onnx (48.3 MB)
#
# Export complete (2.6s)
# Results saved to /content/drive/MyDrive/sportimization-5/sportimization-54/weights
# Detect:          python detect.py --weights /content/drive/MyDrive/sportimization-5/sportimization-54/weights/best_striped.onnx --half
# Validate:        python val.py --weights /content/drive/MyDrive/sportimization-5/sportimization-54/weights/best_striped.onnx --half
# ...
