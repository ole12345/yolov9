# %%
# !git clone https://github.com/ole12345/yolov9.git

# %%
# %cd yolov9
# !pip install -r requirements.txt --quiet

# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /content/yolov9

# %%
# !mkdir -p {HOME}/weights
# !wget -P {HOME}/weights -q https://github.com/WongKinYiu/yolov9/releases/download/v0.1/gelan-c.pt
# !wget -P {HOME}/weights -q https://github.com/WongKinYiu/yolov9/releases/download/v0.1/gelan-s.pt

# %%
import os
import roboflow

#DATASET_NAME = "football-players-detection-3zvbc-snapb"
DATASET_NAME="ball-player-big"
roboflow.login()

rf = roboflow.Roboflow()
project = rf.workspace("ws-tmip7").project(DATASET_NAME)
dataset = project.version(1).download(model_format="yolov7",location=os.path.join(".","data",DATASET_NAME))

# %% [markdown]
# --weights for transfer learning
# --resume for continuing training!

# %%
python train.py --batch=16 --epochs 100 --img 640 --device 0 --min-items 0 --close-mosaic 15 --data data/ball-player-big/data.yaml --weights /weights/best.pt --cfg models/detect/gelan-c-nc_2.yaml --hyp hyp.scratch-high.yaml --name exp-6 --workers 12

# %%
# !pip install onnx onnxruntime onnx-simplifier onnxruntime-gpu

# %%
import export
export.run(include=['onnx'],weights=r"\weights/best_striped.pt",imgsz=(640,640),batch_size=1,opset=20,simplify=True)
